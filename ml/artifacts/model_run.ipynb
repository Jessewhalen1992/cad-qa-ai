# %% [markdown]
# # Layer Classifier Training
#
# Run this notebook from the project root (`CAD AI`) to build a fitted `layer_clf.pkl`.

# %%
import pathlib, pandas as pd, joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Use the notebook’s working directory to locate your repo
repo_root = pathlib.Path().resolve()
data_path = repo_root / "ml" / "datasets" / "labeled.csv"
assert data_path.exists(), f"{data_path} not found"

df = pd.read_csv(data_path, on_bad_lines="skip").dropna(subset=["Content", "Layer"])

# Pipeline with TF–IDF and a Logistic Regression classifier
pipe = Pipeline([
    ("tfidf", TfidfVectorizer(token_pattern=r"[A-Za-z0-9\\.]+")),
    ("clf", LogisticRegression(max_iter=1000, multi_class="auto"))
])

# %%
# Train/test split and fit
X_train, X_test, y_train, y_test = train_test_split(
    df['Content'], df['Layer'], test_size=0.2, random_state=42
)

pipe.fit(X_train, y_train)
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
# C:\Users\Jesse 2025\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                                  precision    recall  f1-score   support
#
#                               0       0.56      0.75      0.64      1603
#                              10       0.00      0.00      0.00         1
#                              12       0.00      0.00      0.00         1
#                              13       0.00      0.00      0.00         3
#                              20       0.00      0.00      0.00         4
#                              21       0.00      0.00      0.00        10
#                              26       0.00      0.00      0.00         6
#                              33       0.67      0.25      0.36         8
#                              35       0.72      0.84      0.78        85
#                              37       0.00      0.00      0.00         1
#                              38       0.00      0.00      0.00         4
#                              39       0.00      0.00      0.00         2
#                              40       0.00      0.00      0.00         1
#                              47       0.00      0.00      0.00         1
#                              53       0.00      0.00      0.00         2
#                              55       0.00      0.00      0.00         4
#                               6       0.00      0.00      0.00         3
#                               7       0.00      0.00      0.00         1
#                   ABADATA-DRILL       0.44      0.50      0.47        16
#                 ABADATA-DRILL-T       0.56      0.53      0.54       588
#                AB_SEC_N83UTMz11       0.00      0.00      0.00         1
#                AB_SEC_N83UTMz12       0.00      0.00      0.00         1
#                     AS-BOUNDARY       0.00      0.00      0.00         5
#                        AS-CABLE       0.76      0.76      0.76        34
#                      AS-CABLE-T       0.00      0.00      0.00         1
#                       AS-COUNTY       0.00      0.00      0.00         2
#                      AS-DRILL-T       0.74      0.23      0.35       306
#                        AS-FENCE       0.00      0.00      0.00         7
#             AS-FIBRE-OPTIC-1000       0.00      0.00      0.00         1
#            AS-FIBRE-OPTIC-TELUS       0.00      0.00      0.00         2
#                 AS-FMA BOUNDARY       0.00      0.00      0.00         2
#                        AS-FMA-T       1.00      0.67      0.80        15
#                      AS-GENERAL       0.67      0.12      0.20       154
#                  AS-IR BOUNDARY       0.00      0.00      0.00         1
#                        AS-OWNER       0.23      0.10      0.13       189
#                      AS-PIPE-AG       0.67      0.11      0.19        18
#  AS-PIPE-AG-CLIENT LOW PRESSURE       0.00      0.00      0.00         1
#                    AS-PIPE-AG-T       0.00      0.00      0.00         3
#                    AS-PIPE-RACK       0.00      0.00      0.00         2
#                      AS-PIPE-UG       0.83      0.11      0.19        47
#                  AS-PIPE-UG RED       0.00      0.00      0.00         2
# AS-PIPE-UG-CLIENT HIGH PRESSURE       0.00      0.00      0.00         1
#                    AS-PIPE-UG-T       0.82      0.96      0.88       355
#               AS-PIPE-UG-T-1000       0.00      0.00      0.00         1
#                        AS-POWER       0.71      0.35      0.46       113
#                 AS-POWER-BURIED       0.00      0.00      0.00         1
#  AS-POWER-BURIED-ATCO PIPELINES       0.00      0.00      0.00         5
#               AS-POWER-EXISTING       0.64      0.99      0.78       460
#          AS-POWER-EXISTING-1000       0.00      0.00      0.00         1
#           AS-POWER-EXISTING-ANC       0.00      0.00      0.00        53
#            AS-POWER-EXISTING-PP       0.00      0.00      0.00       195
#       AS-POWER-EXISTING-PP-1000       0.00      0.00      0.00        61
#             AS-POWER-EXISTING-T       0.36      0.62      0.45         8
#         AS-POWER-EXISTING-T-500       0.00      0.00      0.00         1
#      AS-POWER-OH-ATCO PIPELINES       1.00      0.20      0.33         5
#   AS-POWER-OH-ATCO PIPELINES-5K       0.50      1.00      0.67         1
#               AS-POWER-STAKED-T       0.00      0.00      0.00         1
#                      AS-POWER-T       0.61      0.62      0.62       219
#                 AS-POWER-T-1000       0.00      0.00      0.00        40
#             AS-PWER-EXISTING-5K       0.00      0.00      0.00         3
#                      AS-RAILWAY       0.00      0.00      0.00         1
#               AS-RECON EXISTING       0.00      0.00      0.00         8
#             AS-RECON EXISTING-T       0.62      0.90      0.73        20
#        AS-RECON EXISTING-T-1000       0.44      0.40      0.42        10
#                    AS-RESIDENCE       1.00      0.97      0.98       335
#                        AS-ROADS       0.00      0.00      0.00         3
#                     AS-ROUTEMAP       0.00      0.00      0.00         1
#                     AS-SANITARY       0.00      0.00      0.00         1
#                      AS-SEISMIC       0.81      0.89      0.85        44
#                    AS-STRUCTURE       0.00      0.00      0.00        12
#                  AS-STRUCTURE-T       0.28      0.37      0.32        54
#             AS-STRUCTURE-T-1000       0.00      0.00      0.00         1
#               AS-SURFACE IMPACT       0.00      0.00      0.00        46
#                       AS-SYMBOL       0.86      0.89      0.88       943
#                  AS-SYMBOL-1000       0.00      0.00      0.00        94
#                   AS-SYMBOL-500       0.00      0.00      0.00         1
#               AS-Sewer San_1000       0.42      0.71      0.53         7
#                   AS-TARGET-GAS       0.98      1.00      0.99        84
#                   AS-TARGET-OIL       1.00      1.00      1.00        21
#                    AS-TELEPHONE       0.00      0.00      0.00        14
#                  AS-TELEPHONE-T       0.46      0.83      0.59       102
#             AS-TELEPHONE-T-1000       1.00      0.21      0.35        14
#                        AS-TELUS       0.00      0.00      0.00        69
#         AS-TELUS-ATCO PIPELINES       0.00      0.00      0.00        16
#             AS-TRAPPER BOUNDARY       0.75      0.60      0.67         5
#                    AS-TRAPPER-T       0.93      0.99      0.96        69
#                   AS-WATER PIPE       0.00      0.00      0.00         1
#                     AS-WILDLIFE       0.87      0.92      0.90       118
#               AS-WILDLIFE-BLOCK       0.39      0.20      0.26       137
#                          ASHADE       1.00      1.00      1.00         9
#                      AUX-BUFFER       0.97      0.99      0.98        73
#                      AUX-LABELS       0.83      1.00      0.91         5
#                            C-AR       0.00      0.00      0.00        22
#                          C-AR-T       0.84      0.77      0.80       781
#                         C-EZE-T       0.75      0.36      0.49        25
#                      C-FLOWLINE       0.00      0.00      0.00         2
#                    C-FLOWLINE-T       0.70      0.83      0.76       103
#                C-ROAD-PROF-TEXT       0.25      0.03      0.06        32
#                C-ROAD-PROF-TITL       1.00      1.00      1.00         1
#                            C-RW       0.00      0.00      0.00        33
#                          C-RW-T       0.83      0.79      0.81      1291
#                         C-RW-T2       0.00      0.00      0.00         3
#                        C-SYMBOL       0.99      0.92      0.95       572
#                      C-SYMBOL-2       0.00      0.00      0.00         1
#                            C-WS       0.00      0.00      0.00         8
#                          C-WS-S       0.52      0.89      0.66       813
#                          C-WS-T       0.74      0.72      0.73       726
#                        CG-NORTH       0.00      0.00      0.00         2
#                        CG-NOTES       0.45      0.73      0.56      1171
#                   CG-NOTES-1000       0.00      0.00      0.00        28
#                     CG-REVISION       0.00      0.00      0.00         1
#                   CG-SIGNATURES       0.00      0.00      0.00         6
#                      CHAINAGE-T       0.00      0.00      0.00        21
#                     CORRIDOR-ID       1.00      1.00      1.00         2
#                           D-TXT       0.93      0.98      0.95       427
#                      D-TXT-1000       0.00      0.00      0.00        10
#                     DESCRIPTION       0.00      0.00      0.00         1
#              DETAIL-HZ-Existing       0.82      0.62      0.71        58
#                        DETAIL-T       0.70      0.64      0.67       661
#                      DISCLAIMER       0.00      0.00      0.00        30
#                         DRILL-T       0.64      0.29      0.40       237
#     EXISTING PIPE (EXIST OR HP)       0.83      0.62      0.71         8
#              EXISTING PIPE IP-T       0.00      0.00      0.00         1
#                            F-AR       0.00      0.00      0.00         4
#                          F-AR-T       0.74      0.83      0.78       648
#                           F-EZE       0.00      0.00      0.00         7
#                         F-EZE-T       0.85      0.91      0.88       411
#                    F-FLOWLINE-T       0.62      0.52      0.57        29
#                            F-RW       0.00      0.00      0.00        58
#                          F-RW-T       0.83      0.88      0.85      1948
#                         F-RW-T1       0.00      0.00      0.00         1
#                         F-RW-T2       0.00      0.00      0.00         4
#                         F-RW-T3       0.00      0.00      0.00         1
#                         F-VCE-T       0.83      0.29      0.43        17
#                            F-WS       0.00      0.00      0.00        14
#                          F-WS-S       0.67      0.35      0.46       773
#                     F-WS-S-1000       0.00      0.00      0.00         2
#                          F-WS-T       0.62      0.81      0.70       603
#                     F-WS-T-1000       1.00      0.43      0.61        23
#                   FEATURE_LABEL       0.86      0.72      0.78        25
#                             L-2       0.00      0.00      0.00        23
#                            L-33       0.91      0.96      0.93        45
#                       L-33-1000       0.00      0.00      0.00         1
#                  L-AREAREQUIRED       0.85      0.89      0.87       179
#                L-AREAREQUIRED-1       0.00      0.00      0.00         1
#                 L-AREAREQUIRED2       0.00      0.00      0.00         1
#                      L-AREAWORK       0.62      0.62      0.62        48
#                            L-BD       0.64      0.88      0.74      2258
#                          L-BD 0       0.00      0.00      0.00         2
#                          L-BD 2       0.00      0.00      0.00         1
#                           L-BD1       0.58      0.16      0.25       742
#                          L-DESC       0.00      0.00      0.00         1
#                      L-DETAIL-T       0.85      0.71      0.77        78
#                          L-MECH       0.94      1.00      0.97        68
#                           L-MON       0.93      0.98      0.95      4490
#                         L-MON 1       0.00      0.00      0.00         1
#                      L-MON-1000       0.00      0.00      0.00        70
#                      L-MON-PLAN       0.00      0.00      0.00         1
#                         L-MON-T       0.73      0.07      0.13       160
#                    L-MON-T-1000       0.00      0.00      0.00         3
#                          L-QSEC       0.69      0.72      0.70        43
#                        L-ROAD-T       0.96      0.99      0.97       756
#                   L-ROAD-T-1000       0.90      0.27      0.42        33
#                           L-SEC       0.00      0.00      0.00        15
#                        L-SEC-HB       0.00      0.00      0.00         1
#                        L-SECLBL       1.00      0.93      0.96       601
#                          L-SECQ       0.55      0.42      0.48        26
#                   L-SECTION-LSD       1.00      0.99      1.00       990
#                        L-SYMBOL       0.00      0.00      0.00         8
#                           L-TIE       0.45      0.90      0.60        10
#                         L-TIE-T       1.00      0.04      0.09        67
#                       L-TITLEDB       0.52      0.31      0.39        90
#                     L-TITLEDB-T       0.79      0.91      0.84       580
#                L-TITLEDB-T-1000       0.92      0.77      0.84       121
#                          L-TRAV       0.00      0.00      0.00         1
#                         L-UNS-T       0.97      1.00      0.98       361
#                          L-USEC       0.93      0.68      0.79        19
#                          L-WATR       0.71      1.00      0.83         5
#                       M-DETAILS       1.00      1.00      1.00        17
#         P-100m WELL BORE BUFFER       0.00      0.00      0.00        31
#             P-75m DRAINAGE AREA       0.00      0.00      0.00         5
#      P-ALTAGAS RECON-10m BUFFER       0.00      0.00      0.00         1
#          P-APEX RECON PAY ITEMS       0.40      0.09      0.15        88
#     P-APEX RECON PAY ITEMS-1000       0.10      0.01      0.02       141
#          P-APEX RECON-LINE LIST       0.53      0.49      0.51        37
#     P-APEX RECON-LINE LIST-1000       0.00      0.00      0.00        18
#              P-APEX RECON-TWS-T       0.54      0.53      0.53        80
#         P-APEX RECON-TWS-T-1000       0.00      0.00      0.00        64
#                          P-BORE       1.00      0.69      0.81        16
#                P-BUFFER-CIOOC-T       0.00      0.00      0.00         4
#                 P-BUFFER-PURPLE       0.00      0.00      0.00         1
#               P-BUFFER-PURPLE-T       1.00      0.33      0.50         9
#                      P-BUFFER-T       0.82      0.96      0.89        77
#               P-BUFFER-YELLOW-T       1.00      1.00      1.00         3
#                    P-CHAINAGE-T       0.00      0.00      0.00        22
#                     P-CROSSINGS       0.95      0.99      0.97      1469
#                  P-CROSSINGS AR       0.00      0.00      0.00         5
#                P-CROSSINGS-1000       0.00      0.00      0.00        56
#                   P-CROSSINGS-T       0.00      0.00      0.00         1
#                   P-CROSSINGS_2       0.00      0.00      0.00         2
#              P-D56-0.5km RADIUS       0.00      0.00      0.00         1
#                       P-D56-EPZ       0.00      0.00      0.00         1
#                     P-ELEVATION       0.40      0.24      0.30        97
#                  P-FNC BUFFER-T       0.00      0.00      0.00         7
#                          P-IOP2       0.00      0.00      0.00         1
#                       P-OFFSETS       1.00      1.00      1.00        17
#                    P-PDRILLPATH       0.00      0.00      0.00         2
#                P-POWER BUFFER-T       0.00      0.00      0.00         2
#                    P-PROPOSED-H       0.00      0.00      0.00         1
#                    P-PROPOSED-T       0.75      0.67      0.71        18
#                  P-PROPOSED-WL1       0.00      0.00      0.00         1
#                  P-PROPOSED-WL2       0.00      0.00      0.00        13
#                 P-PROPOSED-WL2b       0.00      0.00      0.00         2
#                  P-PROPOSED-WL3       0.00      0.00      0.00         1
#                  P-PROPOSED-WL4       0.00      0.00      0.00         1
#                  P-PROPOSED-WL5       1.00      0.33      0.50         6
#                       P-STATION       0.57      0.21      0.30       226
#         P-TEMP-ATCO PIPELINES-T       0.00      0.00      0.00         1
#       P-TEMP-ATCO PIPELINES-T_1       0.00      0.00      0.00         4
#       P-TEMP-ATCO PIPELINES-T_2       0.00      0.00      0.00         3
#                  P-TEMP-BLOCK-1       0.00      0.00      0.00         1
#                   P-TEMP-BLOCKS       0.38      0.57      0.45       646
#                     P-TEMP-BLUE       0.50      0.75      0.60         4
#                   P-TEMP-BLUE-T       0.56      0.79      0.65        62
#                  P-TEMP-BLUE-T2       0.00      0.00      0.00         1
#                        P-TEMP-H       0.20      1.00      0.33         1
#                 P-TEMP-NO CUT-T       1.00      0.75      0.86         4
#                        P-TEMP-T       0.69      0.49      0.57        74
#                       P-TEMP-T1       0.00      0.00      0.00         2
#                      P-TEMP-T10       0.00      0.00      0.00         2
#                       P-TEMP-T3       0.00      0.00      0.00         5
#                       P-TEMP-T4       0.00      0.00      0.00         1
#                       P-TEMP-T5       0.00      0.00      0.00         1
#                       P-TEMP-T6       0.00      0.00      0.00         2
#                       P-TEMP-T7       0.00      0.00      0.00         2
#                       P-TEMP-T8       0.00      0.00      0.00         1
#               P-TEMP_BORROW PIT       0.00      0.00      0.00         2
#                P-TEMP_WORKSPACE       0.00      0.00      0.00         5
#              P-TEMP_WORKSPACE 1       0.00      0.00      0.00         1
#                          P-TRAV       0.00      0.00      0.00         1
#                           P-TXT       0.77      0.76      0.77       256
#                          P-TXT2       0.00      0.00      0.00         1
#                      P-WORKAREA       0.00      0.00      0.00         2
#                    P-WORKAREA-T       0.00      0.00      0.00         2
#                  PROPOSED-SCOPE       0.00      0.00      0.00         1
#                  Parcel Mapping       0.00      0.00      0.00         2
#                         R- CONC       0.00      0.00      0.00         1
#                        R- HOUSE       0.00      0.00      0.00         1
#               ROUTE MAP BUBBLES       0.00      0.00      0.00         5
#                  ROUTE MAP DOTS       0.00      0.00      0.00         9
#                ROUTE-MAP-LABELS       0.00      0.00      0.00         6
#                 ROUTE-MAP-ROUTE       0.00      0.00      0.00         1
#                             S-3       0.00      0.00      0.00         3
#                             S-4       0.00      0.00      0.00         3
#                            S-40       0.00      0.00      0.00         7
#                       S-SYMBOLS       0.00      0.00      0.00         1
#                            S-T7       0.25      0.03      0.05        66
#                           SECNO       0.00      0.00      0.00         4
#                          T-BUSH       0.00      0.00      0.00        21
#                        T-BUSH-T       0.97      0.99      0.98       641
#                         T-CREEK       0.00      0.00      0.00         2
#                    T-CREEK-TEXT       0.00      0.00      0.00         1
#                          T-DRAW       0.00      0.00      0.00         3
#                  T-EXISTING RTF       0.00      0.00      0.00         7
#                T-EXISTING RTF-T       0.00      0.00      0.00         9
#                T-EXISTING TFA-T       0.85      0.85      0.85        65
#                       T-GENERAL       1.00      0.72      0.84        83
#                      T-LOW-AREA       0.00      0.00      0.00         5
#                    T-LOW-AREA-T       0.00      0.00      0.00         7
#                         T-SLOPE       0.00      0.00      0.00        12
#                          T-TEXT       0.83      0.92      0.87      1557
#                     T-TEXT-1000       0.70      0.19      0.30        37
#                           T-TIE       1.00      0.15      0.27        13
#                         T-TIE-T       1.00      0.03      0.05        80
#                         T-WATER       0.00      0.00      0.00        21
#                       T-WATER-T       0.88      0.95      0.92       399
#                  T-WATER-T-1000       0.00      0.00      0.00         2
#                         WETLAND       0.00      0.00      0.00        12
#                       WETLAND-T       0.89      0.91      0.90       183
#                        licensee       0.00      0.00      0.00         1
#                             uwi       0.00      0.00      0.00         4
#
#                        accuracy                           0.76     37431
#                       macro avg       0.31      0.27      0.27     37431
#                    weighted avg       0.74      0.76      0.73     37431
# C:\Users\Jesse 2025\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Jesse 2025\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Jesse 2025\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
out_path = repo_root / "ml" / "artifacts" / "layer_clf.pkl"
assert hasattr(pipe.named_steps["tfidf"], "vocabulary_")  # make sure fitted
out_path.parent.mkdir(parents=True, exist_ok=True)  # ensure the directory exists
joblib.dump(pipe, out_path)
print("✓ Model saved to", out_path)
# Out:
# ✓ Model saved to C:\Users\Jesse 2025\Desktop\CAD AI\ml\artifacts\layer_clf.pkl
